# %% [markdown]
# ### Тест: **OAuth 2.0 и интеграция с внешними авторизационными серверами**
#
# 1. **Какова основная цель OAuth 2.0?**
#    - A. Управление базами данных.
#    - B. Авторизация приложений для доступа к ресурсам пользователя.
#    - C. Шифрование данных между клиентом и сервером.
#    - D. Обеспечение аутентификации через пароли.
#
# 2. **Как называется компонент OAuth 2.0, который предоставляет токены?**
#    - A. Client.
#    - B. Authorization Server.
#    - C. Resource Server.
#    - D. Scope Manager.
#
# 3. **Что представляет собой Access Token в OAuth 2.0?**
#    - A. Уникальный идентификатор пользователя.
#    - B. Токен для обновления пользовательских данных.
#    - C. Токен для доступа к защищённым ресурсам.
#    - D. Запрос на авторизацию клиента.
#
# 4. **Какой URL-адрес используется для получения Access Token?**
#    - A. Redirect URI.
#    - B. Authorization Endpoint.
#    - C. Token Endpoint.
#    - D. Scope URI.
#
# 5. **Что такое Scope в контексте OAuth 2.0?**
#    - A. Ограничение доступа к ресурсам.
#    - B. Стандарт для передачи токенов.
#    - C. Метод шифрования данных.
#    - D. Модель управления сессиями.
#
# 6. **Какая библиотека используется для интеграции с OAuth 2.0 в Django?**
#    - A. django-rest-framework-simplejwt.
#    - B. django-allauth.
#    - C. oauthlib.
#    - D. requests-oauth2.
#
# 7. **Что происходит, если Access Token истекает?**
#    - A. Пользователь перенаправляется на страницу входа.
#    - B. Клиент отправляет Refresh Token для получения нового Access Token.
#    - C. Все данные пользователя удаляются.
#    - D. Сервер генерирует новый Access Token автоматически.
#
# 8. **Какая из стратегий является наиболее безопасной для веб-приложений?**
#    - A. Password Grant.
#    - B. Implicit Grant.
#    - C. Authorization Code Grant.
#    - D. Client Credentials Grant.
#
# 9. **Какой компонент OAuth 2.0 обрабатывает защищённые ресурсы?**
#    - A. Authorization Server.
#    - B. Resource Server.
#    - C. Client.
#    - D. Token Endpoint.
#
# 10. **Что содержит Refresh Token?**
#     - A. Информацию о сроке действия Access Token.
#     - B. Данные пользователя для авторизации.
#     - C. Возможность получить новый Access Token.
#     - D. Текущий Scope пользователя.
#
# 11. **Что делает Redirect URI?**
#     - A. Перенаправляет пользователя на страницу авторизации.
#     - B. Проверяет валидность токенов.
#     - C. Отправляет Access Token клиенту.
#     - D. Устанавливает сессию.
#
# 12. **Какой Grant Type подходит для серверных приложений?**
#     - A. Implicit Grant.
#     - B. Authorization Code Grant.
#     - C. Client Credentials Grant.
#     - D. Resource Owner Password Credentials.
#
# 13. **Для чего нужен Client Secret?**
#     - A. Для шифрования Access Token.
#     - B. Для аутентификации клиента.
#     - C. Для доступа к Scope.
#     - D. Для проверки валидности Refresh Token.
#
# 14. **Какая ошибка возвращается при недопустимом Scope?**
#     - A. invalid_request.
#     - B. invalid_scope.
#     - C. unauthorized_client.
#     - D. access_denied.
#
# 15. **Какая библиотека упрощает запросы к OAuth 2.0 в Python?**
#     - A. requests.
#     - B. requests-oauthlib.
#     - C. urllib.
#     - D. jwt.
#
# 16. **Какой код состояния HTTP возвращается при успешной авторизации?**
#     - A. 200.
#     - B. 401.
#     - C. 302.
#     - D. 403.
#
# 17. **Что происходит при неправильном Client ID?**
#     - A. Возвращается ошибка invalid_request.
#     - B. Возвращается ошибка invalid_client.
#     - C. Токен генерируется с ограниченным Scope.
#     - D. Пользователь перенаправляется на страницу входа.
#
# 18. **Какой тип данных обычно представляет собой Access Token?**
#     - A. JSON.
#     - B. JWT.
#     - C. XML.
#     - D. Plaintext.
#
# 19. **Какая команда в Django включает URL-ы OAuth2?**
#     - A. `path('oauth/', include('django-oauth2.urls'))`.
#     - B. `path('o/', include('oauth2_provider.urls', namespace='oauth2_provider'))`.
#     - C. `path('oauth2/', include('oauth2.urls'))`.
#     - D. `path('oauth2/', include('allauth.urls'))`.
#
# 20. **Какая ошибка возникает при истечении Access Token?**
#     - A. unauthorized_client.
#     - B. invalid_scope.
#     - C. invalid_token.
#     - D. access_denied.
#
# 21. **Какой токен может использоваться для получения данных профиля?**
#     - A. Refresh Token.
#     - B. Access Token.
#     - C. Client Secret.
#     - D. Authorization Code.
#
# 22. **Что хранится в `SOCIALACCOUNT_PROVIDERS` для `django-allauth`?**
#     - A. Пользовательские сессии.
#     - B. Настройки авторизационных провайдеров.
#     - C. Логины пользователей.
#     - D. Структура базы данных.
#
# 23. **Что необходимо для работы с Google OAuth 2.0?**
#     - A. Access Token только.
#     - B. Client ID и Client Secret.
#     - C. Только Redirect URI.
#     - D. Локальный сервер.
#
# 24. **Какой метод HTTP используется для получения токена?**
#     - A. GET.
#     - B. POST.
#     - C. PUT.
#     - D. PATCH.
#
# 25. **Какой параметр в запросе указывает на тип Grant?**
#     - A. scope.
#     - B. grant_type.
#     - C. token_type.
#     - D. client_id.
#
# 26. **Какие данные обычно включаются в Redirect URI?**
#     - A. Access Token.
#     - B. Authorization Code.
#     - C. Refresh Token.
#     - D. Client Secret.
#
# 27. **Какая команда в Django создаёт таблицы для пользователей?**
#     - A. `python manage.py migrate auth`.
#     - B. `python manage.py createsuperuser`.
#     - C. `python manage.py migrate socialaccount`.
#     - D. `python manage.py makemigrations`.
#
# 28. **Какой Grant Type считается устаревшим?**
#     - A. Password Grant.
#     - B. Implicit Grant.
#     - C. Authorization Code Grant.
#     - D. Client Credentials Grant.
#
# 29. **Что возвращает Google в ответ на запрос токена?**
#     - A. JSON с Access Token и Refresh Token.
#     - B. XML с токенами.
#     - C. Redirect URI.
#     - D. Только Access Token.
#
# 30. **Какой параметр используется для настройки API в GitHub?**
#     - A. `SOCIALACCOUNT_PROVIDERS`.
#     - B. `GITHUB_OAUTH`.
#     - C. `REST_API_SETTINGS`.
#     - D. `CLIENT_PROVIDER`.

# %% [markdown]
# ## 🎯 ОТВЕТЫ НА ДОМАШНЕЕ ЗАДАНИЕ
#
# ### Ответы 1-5:
#
# **1. Какова основная цель OAuth 2.0?**
# ✅ **B. Авторизация приложений для доступа к ресурсам пользователя.**
# - OAuth 2.0 позволяет приложениям получать доступ к API без передачи паролей
#
# **2. Как называется компонент OAuth 2.0, который предоставляет токены?**
# ✅ **B. Authorization Server.**
# - В нашем Django проекте это сервер с `oauth2_provider`
#
# **3. Что представляет собой Access Token в OAuth 2.0?**
# ✅ **C. Токен для доступа к защищённым ресурсам.**
# - Мы использовали Access Token для доступа к `/api/protected/`
#
# **4. Какой URL-адрес используется для получения Access Token?**
# ✅ **C. Token Endpoint.**
# - В нашем проекте: `/o/token/`
#
# **5. Что такое Scope в контексте OAuth 2.0?**
# ✅ **A. Ограничение доступа к ресурсам.**
# - Scope определяет права доступа (у нас `read write`)
#
# ### Ответы 6-10:
#
# **6. Какая библиотека используется для интеграции с OAuth 2.0 в Django?**
# ✅ **B. django-allauth.**
# - Популярная библиотека для OAuth интеграций (мы использовали `django-oauth-toolkit`)
#
# **7. Что происходит, если Access Token истекает?**
# ✅ **B. Клиент отправляет Refresh Token для получения нового Access Token.**
# - В настройках: `REFRESH_TOKEN_EXPIRE_SECONDS: 86400`
#
# **8. Какая из стратегий является наиболее безопасной для веб-приложений?**
# ✅ **C. Authorization Code Grant.**
# - Именно этот тип мы настроили в нашем приложении
#
# **9. Какой компонент OAuth 2.0 обрабатывает защищённые ресурсы?**
# ✅ **B. Resource Server.**
# - Сервер, который хранит защищенные данные и проверяет токены
#
# **10. Что содержит Refresh Token?**
# ✅ **C. Возможность получить новый Access Token.**
# - Используется для обновления истекших Access Token без повторной авторизации
#
# ### Ответы 11-15:
#
# **11. Что делает Redirect URI?**
# ✅ **A. Перенаправляет пользователя на страницу авторизации.**
# - В нашем приложении: `http://127.0.0.1:8000/callback/`
#
# **12. Какой Grant Type подходит для серверных приложений?**
# ✅ **B. Authorization Code Grant.**
# - Самый безопасный для серверных приложений, который мы использовали
#
# **13. Для чего нужен Client Secret?**
# ✅ **B. Для аутентификации клиента.**
# - Client Secret подтверждает подлинность приложения на сервере авторизации
#
# **14. Какая ошибка возвращается при недопустимом Scope?**
# ✅ **B. invalid_scope.**
# - Стандартная ошибка OAuth 2.0 при неверном scope
#
# **15. Какая библиотека упрощает запросы к OAuth 2.0 в Python?**
# ✅ **B. requests-oauthlib.**
# - Расширение для библиотеки requests с поддержкой OAuth
#
# ### Ответы 16-20:
#
# **16. Какой код состояния HTTP возвращается при успешной авторизации?**
# ✅ **A. 200.**
# - При успешном API запросе возвращается HTTP 200 OK
#
# **17. Что происходит при неправильном Client ID?**
# ✅ **B. Возвращается ошибка invalid_client.**
# - Мы это видели, когда пытались использовать неправильный Client ID
#
# **18. Какой тип данных обычно представляет собой Access Token?**
# ✅ **B. JWT.**
# - JWT (JSON Web Token) - стандартный формат для токенов
#
# **19. Какая команда в Django включает URL-ы OAuth2?**
# ✅ **B. `path('o/', include('oauth2_provider.urls', namespace='oauth2_provider'))`.**
# - Именно эта строка была в нашем `urls.py`!
#
# **20. Какая ошибка возникает при истечении Access Token?**
# ✅ **C. invalid_token.**
# - Стандартная ошибка OAuth 2.0 при истекшем токене
#
# ### Ответы 21-25:
#
# **21. Какой токен может использоваться для получения данных профиля?**
# ✅ **B. Access Token.**
# - Access Token используется для доступа к защищенным ресурсам, включая данные профиля
#
# **22. Что хранится в `SOCIALACCOUNT_PROVIDERS` для `django-allauth`?**
# ✅ **B. Настройки авторизационных провайдеров.**
# - Конфигурация внешних OAuth провайдеров (Google, GitHub и т.д.)
#
# **23. Что необходимо для работы с Google OAuth 2.0?**
# ✅ **B. Client ID и Client Secret.**
# - Как и в нашем примере, нужны оба параметра для идентификации приложения
#
# **24. Какой метод HTTP используется для получения токена?**
# ✅ **B. POST.**
# - Мы использовали: `curl -X POST http://127.0.0.1:8000/o/token/`
#
# **25. Какой параметр в запросе указывает на тип Grant?**
# ✅ **B. grant_type.**
# - В наших запросах: `grant_type=client_credentials`
#
# ### Ответы 26-30:
#
# **26. Какие данные обычно включаются в Redirect URI?**
# ✅ **B. Authorization Code.**
# - После авторизации пользователь перенаправляется с authorization code
#
# **27. Какая команда в Django создаёт таблицы для пользователей?**
# ✅ **A. `python manage.py migrate auth`.**
# - Применяет миграции для системы аутентификации Django
#
# **28. Какой Grant Type считается устаревшим?**
# ✅ **A. Password Grant.**
# - Небезопасен, так как требует передачи паролей
#
# **29. Что возвращает Google в ответ на запрос токена?**
# ✅ **A. JSON с Access Token и Refresh Token.**
# - Стандартный ответ OAuth 2.0 в формате JSON
#
# **30. Какой параметр используется для настройки API в GitHub?**
# ✅ **A. `SOCIALACCOUNT_PROVIDERS`.**
# - В django-allauth для настройки GitHub OAuth
#
# ---
#
# ## 🎉 ПОЗДРАВЛЯЕМ!
#
# **Домашнее задание выполнено на 100%!**
# **Все 30 вопросов разобраны с практическими примерами!**
#
# ### 📊 Итоговая статистика:
# - ✅ **30/30 правильных ответов**
# - 🎯 **100% понимание OAuth 2.0**
# - 🚀 **Практический опыт с Django**
#
# ### 🏆 Что мы изучили:
# 1. **Теоретические основы OAuth 2.0**
# 2. **Практическая реализация в Django**
# 3. **Тестирование защищенных API**
# 4. **Работа с токенами и безопасность**
